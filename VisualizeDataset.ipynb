# %% [markdown]
# # Data Visualistation
# This file is intended to give an overview of the data set used

# %%
import Data_preparation as DP #load some functions for data handling and visualisation 
import pandas as pd
from sklearn import datasets

# import some data to play with
iris = datasets.load_iris()
DP = DP.Data_preparation() # initialize the Data preparation class

# %% [markdown]
# ### Load the Dataset

# %%
df=DP.load_csv_to_df("ricsData_big_v5.csv")
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# ### Draw a Scatterplot for the features

# %%
DP.draw_scatterplot(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Hochschule\WS21_22\KI1\Programme\Vorles_tensorflow\tens\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Hochschule\WS21_22\KI1\Programme\Vorles_tensorflow\tens\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Hochschule\WS21_22\KI1\Programme\Vorles_tensorflow\tens\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5324\661127734.py in <module>
# ----> 1 DP.draw_scatterplot(df)
#
# c:\Hochschule\WS21_22\KI1\Programme\Vorles_tensorflow\Aufgabe\Data_preparation.py in draw_scatterplot(self, df)
#      79               2: 'Korkenzieher'}  # dictionary
#      80
# ---> 81         before = sns.pairplot(df.replace({'Label': di}), hue='Label')
#      82         before.fig.suptitle('Pair Plot of Dataset', y=1.08)
#      83
#
# c:\Hochschule\WS21_22\KI1\Programme\Vorles_tensorflow\tens\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\Hochschule\WS21_22\KI1\Programme\Vorles_tensorflow\tens\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2094     # Set up the PairGrid
#    2095     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2096     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2097                     hue_order=hue_order, palette=palette, corner=corner,
#    2098                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#
# c:\Hochschule\WS21_22\KI1\Programme\Vorles_tensorflow\tens\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\Hochschule\WS21_22\KI1\Programme\Vorles_tensorflow\tens\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, corner, diag_sharey, height, aspect, layout_pad, despine, dropna, size)
#    1287             # to the axes-level functions, while always handling legend creation.
#    1288             # See GH2307
# -> 1289             hue_names = hue_order = categorical_order(data[hue], hue_order)
#    1290             if dropna:
#    1291                 # Filter NA from the list of unique hue names
#
# c:\Hochschule\WS21_22\KI1\Programme\Vorles_tensorflow\tens\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# c:\Hochschule\WS21_22\KI1\Programme\Vorles_tensorflow\tens\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Label'

# %% [markdown]
# ### Draw a correlation Matrix for the features

# %%
DP.draw_corr_matrix(df)
