# %%
import pandas as pd

# %%
df = pd.read_csv('ric.csv',usecols=['Rel_BreitGroß','RelSpitze_oben','RelSpitze_unten','Anzahl_Linie','Anzahl_Kreis','Label'])
print(df)
df.values.tolist()
# Out:
#     Rel_BreitGroß  RelSpitze_oben  RelSpitze_unten  Anzahl_Linie  \
# 1        0.413136        0.810256         0.894017            26
# 2        0.776952        0.813397         0.858852             7
# 3        0.558824        0.447368         0.723684            18
# 4        0.701493        0.258359         0.544073             2
# 5        0.821337        0.871674         0.909233             1
# 6        0.658228        0.828671         0.907343             5
# 7        0.665698        0.599709         0.912664            30
# 8        0.659033        0.992278         0.996139             0
# 9        0.300926        0.426923         0.396154            12
# 10       0.608262        0.962529         1.000000            24
# 11       0.630986        0.627232         0.930804            14
# 12       0.388697        0.667656         0.869436            28
# 13       0.336018        1.000000         0.907534            12
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <module>
# ----> 1 for zeile in reader:
#       2     print(zeile)
#
# ValueError: I/O operation on closed file.
